# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
data = pd.read_csv('insurance.csv')
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.drop_duplicates(inplace = True)
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
data['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data['children'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4], dtype=int64)

# %%
data['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
data.age.unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %%
plt.figure(figsize=(12, 6), dpi=200)
sns.boxplot(y='charges', x='sex', hue='smoker', data=data)
plt.show()

# %%
plt.figure(figsize=(12, 6), dpi=200)
sns.barplot(y='charges', x='sex', hue='smoker', data=data)
plt.show()

# %% [markdown]
# comparitively male smokers are high in this case.

# %%
plt.figure(figsize = (12,6), dpi = 200)
sns.boxplot(hue='children', y='charges',x ='sex', data = data, palette= 'Set1')
plt.show()

# %%
plt.figure(figsize = (12,6), dpi = 200)
sns.barplot(hue='children', y='charges',x ='sex', data = data, palette= 'Set3')
plt.show()

# %%
#  anchargesd smoker
plt.figure(figsize = (12,6), dpi = 200)
sns.scatterplot(hue='children', x='smoker', y='charges', data = data)
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
# sex and smokers
plt.figure(figsize = (16,5), dpi = 200)
plt.subplot(1,2,1)
sns.barplot(x= 'sex', y= 'bmi', data = data)
plt.subplot(1,2,2)
sns.boxplot(x= 'sex', y= 'bmi', data = data)
# Out:
# <Axes: xlabel='sex', ylabel='bmi'>

# %%
# sex and smokers
plt.figure(figsize = (16,5), dpi = 200)

sns.lineplot(x= 'age', y= 'bmi', data = data, ci = None)
plt.title('Line Plot for Age and BMI')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize = (12,6), dpi =200)
sns.scatterplot(x= 'age', y= 'bmi', hue ='sex',data = data)
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
plt.figure(figsize = (12,6), dpi =200)
sns.barplot(x= 'children', y= 'charges', data = data)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %%
plt.figure(figsize = (12,6), dpi =200)
sns.barplot(x= 'sex', y= 'charges', data = data)
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
plt.figure(figsize = (12,6), dpi =200)
sns.boxplot(x= 'children', y= 'charges', data = data)
# Out:
# <Axes: xlabel='children', ylabel='charges'>

# %% [markdown]
# here charges varies depend on the age

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109344  0.041536  0.298308
# bmi       0.109344  1.000000  0.012755  0.198401
# children  0.041536  0.012755  1.000000  0.067389
# charges   0.298308  0.198401  0.067389  1.000000

# %%
plt.figure(figsize = (12,5), dpi =200)
sns.heatmap(data.corr(), annot = True, cmap ='viridis')
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# Checking Correlation
cols = ['age', 'sex', 'bmi', 'smoker', 'region', 'charges']
plt.figure(figsize = (12,6), dpi = 200)
sns.heatmap(data[cols].corr(), annot = True)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
cols = ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
X = data[cols]                      # Independent Feature Set
Y = data[['charges']]   # Depedent Feature

# %%
X.head(10)
# Out:
#    age     sex     bmi  children smoker     region
# 0   19  female  27.900         0    yes  southwest
# 1   18    male  33.770         1     no  southeast
# 2   28    male  33.000         3     no  southeast
# 3   33    male  22.705         0     no  northwest
# 4   32    male  28.880         0     no  northwest
# 5   31  female  25.740         0     no  southeast
# 6   46  female  33.440         1     no  southeast
# 7   37  female  27.740         3     no  northwest
# 8   37    male  29.830         2     no  northeast
# 9   60  female  25.840         0     no  northwest

# %%
Y.head(10)
# Out:
#        charges
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520
# 5   3756.62160
# 6   8240.58960
# 7   7281.50560
# 8   6406.41070
# 9  28923.13692

# %%
print('Independent Feature Set Shape : ', X.shape)
print('Dependent Feature Shape       : ', Y.shape)
# Out:
# Independent Feature Set Shape :  (1337, 6)
# Dependent Feature Shape       :  (1337, 1)

# %%
# Splitting The Data into training and test sets
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 101)

# %%
print('Training Data Shape   : ', x_train.shape)
print('Training Labels Shape : ', y_train.shape)
print('Testing Data Shape    : ', x_test.shape)
print('Testing Labels Shape  : ', y_test.shape)
# Out:
# Training Data Shape   :  (1069, 6)
# Training Labels Shape :  (1069, 1)
# Testing Data Shape    :  (268, 6)
# Testing Labels Shape  :  (268, 1)

# %%
# Encoding (Dealing with Categorical Data)
cols = ['smoker', 'region', 'sex']
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()

# Fit on train set
encoder.fit(x_train[cols])

# Tranforming the training and testing sets
x_train[cols] = encoder.transform(x_train[cols])
x_test[cols]  = encoder.transform(x_test[cols])

# %%
x_train.head(10)
# Out:
#       age  sex     bmi  children  smoker  region
# 805    45  0.0  35.815         0     0.0     1.0
# 354    18  0.0  38.280         0     0.0     2.0
# 563    50  1.0  44.770         1     0.0     2.0
# 1178   23  0.0  34.865         0     0.0     0.0
# 390    48  1.0  35.625         4     0.0     0.0
# 934    32  1.0  37.180         2     0.0     2.0
# 1099   25  0.0  33.990         1     0.0     2.0
# 709    36  0.0  27.740         0     0.0     0.0
# 1210   36  1.0  30.875         1     0.0     1.0
# 1029   37  0.0  17.290         2     0.0     0.0

# %%
# Scaling
from sklearn.preprocessing import MinMaxScaler

cols = ['age','sex','bmi','children','smoker','region']
scaler = MinMaxScaler()

# Fit on training set
scaler.fit(x_train[cols])

# Transform training and testing sets
x_train[cols] = scaler.transform(x_train[cols])
x_test[cols] = scaler.transform(x_test[cols])

# %%
x_train.head(10)
# Out:
#            age  sex       bmi  children  smoker    region
# 805   0.586957  0.0  0.523200       0.0     0.0  0.333333
# 354   0.000000  0.0  0.591078       0.0     0.0  0.666667
# 563   0.695652  1.0  0.769792       0.2     0.0  0.666667
# 1178  0.108696  0.0  0.497040       0.0     0.0  0.000000
# 390   0.652174  1.0  0.517968       0.8     0.0  0.000000
# 934   0.304348  1.0  0.560788       0.4     0.0  0.666667
# 1099  0.152174  0.0  0.472945       0.2     0.0  0.666667
# 709   0.391304  0.0  0.300840       0.0     0.0  0.000000
# 1210  0.391304  1.0  0.387168       0.2     0.0  0.333333
# 1029  0.413043  0.0  0.013080       0.4     0.0  0.000000

# %%
x_test.head(10)
# Out:
#            age  sex       bmi  children  smoker    region
# 44    0.434783  1.0  0.557208       0.2     0.0  0.000000
# 134   0.043478  0.0  0.329616       0.0     0.0  0.000000
# 981   0.347826  1.0  0.125568       0.0     0.0  0.000000
# 619   0.804348  0.0  0.558585       0.0     0.0  1.000000
# 1239  0.152174  0.0  0.697095       0.2     0.0  0.666667
# 295   0.000000  1.0  0.170040       0.0     0.0  0.000000
# 20    0.913043  0.0  0.528432       0.0     0.0  0.000000
# 1298  0.326087  1.0  0.292992       0.4     0.0  0.333333
# 365   0.673913  0.0  0.384552       0.2     0.0  0.000000
# 671   0.239130  0.0  0.395016       0.0     0.0  0.000000

# %%
encoder.categories_
# Out:
# [array(['no', 'yes'], dtype=object),
#  array(['northeast', 'northwest', 'southeast', 'southwest'], dtype=object),
#  array(['female', 'male'], dtype=object)]

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors = 20)
regressor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=20)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test)

from sklearn.metrics import r2_score
print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test))
# Out:
# Training Set Score :  0.7959152822514365
# Testing Set Score  :  0.7577889111625515

# %%
x_test[:5]
# Out:
#            age  sex       bmi  children  smoker    region
# 44    0.434783  1.0  0.557208       0.2     0.0  0.000000
# 134   0.043478  0.0  0.329616       0.0     0.0  0.000000
# 981   0.347826  1.0  0.125568       0.0     0.0  0.000000
# 619   0.804348  0.0  0.558585       0.0     0.0  1.000000
# 1239  0.152174  0.0  0.697095       0.2     0.0  0.666667

# %%
regressor.predict(x_test[:1])
# Out:
# array([[8148.0545755]])

# %%
regressor.predict(x_test[:5])
# Out:
# array([[ 8148.0545755 ],
#        [ 6469.33893345],
#        [ 5003.279073  ],
#        [11207.38605   ],
#        [ 4459.949462  ]])

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion = 'squared_error',splitter='best' ,max_depth = 5)
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
pred_train = regressor.predict(x_train)
pred_test  = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
print('Training Set Score : ', r2_score(y_train, pred_train))
print('Testing Set Score  : ', r2_score(y_test, pred_test))
# Out:
# Training Set Score :  0.883556284789503
# Testing Set Score  :  0.8317524434465466

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
### regularisation method

# %%
from sklearn.linear_model import Lasso                               # Regression with L1 Regularization
regressor = Lasso(alpha = 1)                                         # alpha : regularization parameter
regressor.fit(x_train, y_train)

print('Training set score : ', regressor.score(x_train, y_train))
print('Testing set score  : ', regressor.score(x_test, y_test))
# Out:
# Training set score :  0.748565694189984
# Testing set score  :  0.755404366832674

# %%
from sklearn.linear_model import Ridge                               # Regression with L2 Regularization
regressor = Ridge(alpha = 0.001)
regressor.fit(x_train, y_train)

print('Training set score : ', regressor.score(x_train, y_train))
print('Testing set score  : ', regressor.score(x_test, y_test))
# Out:
# Training set score :  0.7485662411428213
# Testing set score  :  0.7554458029001271

# %%
from sklearn.linear_model import ElasticNet                               # Regression with L1 and L2 Regularization
regressor = ElasticNet(alpha = 3)
regressor.fit(x_train, y_train)

print('Training set score : ', regressor.score(x_train, y_train))
print('Testing set score  : ', regressor.score(x_test, y_test))
# Out:
# Training set score :  0.13104156056741845
# Testing set score  :  0.11974498139504064
